# %% [markdown]
# <a href="https://colab.research.google.com/github/Karla-cm/notas/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://datos.cdmx.gob.mx/dataset/7593b324-6010-44f7-8132-cb8b2276c842/resource/74364031-d252-4f57-b419-af0a49f0fb0f/download/da_victimas_21-22.csv
# Out:
# --2023-10-02 15:48:51--  https://datos.cdmx.gob.mx/dataset/7593b324-6010-44f7-8132-cb8b2276c842/resource/74364031-d252-4f57-b419-af0a49f0fb0f/download/da_victimas_21-22.csv
# Resolving datos.cdmx.gob.mx (datos.cdmx.gob.mx)... 45.60.242.232
# Connecting to datos.cdmx.gob.mx (datos.cdmx.gob.mx)|45.60.242.232|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 127762753 (122M) [application/octet-stream]
# Saving to: ‘da_victimas_21-22.csv’
#
# da_victimas_21-22.c 100%[===================>] 121.84M  6.11MB/s    in 28s
#
# 2023-10-02 15:49:20 (4.41 MB/s) - ‘da_victimas_21-22.csv’ saved [127762753/127762753]

# %%
import pandas

# %%
df = pandas.read_csv("/content/da_victimas_21-22.csv")

# %%
df
# Out:
#         idCarpeta  Año_inicio Mes_inicio FechaInicio  \
# 0       8828667.0        2021      Enero  2021-01-01
# 1       8828668.0        2021      Enero  2021-01-01
# 2       8828669.0        2021      Enero  2021-01-01
# 3       8828670.0        2021      Enero  2021-01-01
# 4       8828673.0        2021      Enero  2021-01-01
# ...           ...         ...        ...         ...
# 493759  9125395.0        2022    Febrero  2022-02-19
# 493760  9260507.0        2022     Agosto  2022-08-15
# 493761  9168653.0        2022      Abril  2022-04-14
# 493762  9226209.0        2022      Junio  2022-06-30
# 493763  9350466.0        2022  Diciembre  2022-12-13
#
#                                                    Delito  \
# 0                                      VIOLENCIA FAMILIAR
# 1       LESIONES CULPOSAS POR TRANSITO VEHICULAR EN CO...
# 2                       ROBO DE MOTOCICLETA SIN VIOLENCIA
# 3       ROBO DE VEHICULO DE SERVICIO PARTICULAR SIN VI...
# ...

# %%
Delito = df["Delito"]

# %%
Delito
# Out:
# 0                                        VIOLENCIA FAMILIAR
# 1         LESIONES CULPOSAS POR TRANSITO VEHICULAR EN CO...
# 2                         ROBO DE MOTOCICLETA SIN VIOLENCIA
# 3         ROBO DE VEHICULO DE SERVICIO PARTICULAR SIN VI...
# 4         ROBO DE VEHICULO DE SERVICIO PARTICULAR SIN VI...
#                                 ...
# 493759                  PERDIDA DE LA VIDA POR OTRAS CAUSAS
# 493760                                          FEMINICIDIO
# 493761                                             AMENAZAS
# 493762                        LA ADMINISTRACION DE JUSTICIA
# 493763                                 HOMICIDIO POR GOLPES
# Name: Delito, Length: 493764, dtype: object

# %%
Delito_unicos = list(set(Delito))

# %%
Delito_unicos
# Out:
# ['ROBO DE VEHICULO DE SERVICIO PARTICULAR CON VIOLENCIA',
#  'ROBO A PASAJERO EN AUTOBÚS FORÁNEO CON VIOLENCIA',
#  'ROBO A PASAJERO A BORDO DE METRO CON VIOLENCIA',
#  'LESIONES DOLOSAS POR QUEMADURAS',
#  'PERDIDA DE LA VIDA POR SUICIDIO',
#  'PANDILLA, ASOCIACIÓN DELICTUOSA Y DELINCUENCIA ORGANIZADA',
#  'ATAQUES A LA PAZ PUBLICA',
#  'ACOSO SEXUAL AGRAVADO EN CONTRA DE MENORES',
#  'ROBO A PASAJERO EN TREN SUBURBANO SIN VIOLENCIA',
#  'DAÑO EN PROPIEDAD AJENA CULPOSA POR TRÁNSITO VEHICULAR A VIAS DE COMUNICACION',
#  'ROBO A PASAJERO EN ECOBUS CON VIOLENCIA',
#  'COHECHO',
#  'VIOLACION DE CORRESPONDENCIA',
#  'CORRUPCIÓN DE PERSONAS MENORES DE EDAD O PERSONAS QUE NO TENGAN CAPACIDAD PARA COMPRENDER EL SIGNIFICADO DEL HECHO O DE PERSONAS QUE NO TENGAN CAPACIDAD DE RESISTIR LA CONDUCTA',
#  'PERDIDA DE LA VIDA POR ASFIXIA',
#  'ROBO A PASAJERO EN TREN LIGERO SIN VIOLENCIA',
#  'FALSEDAD ANTE AUTORIDADES',
#  'VIOLACION EQUIPARADA POR CONOCIDO',
# ...

# %%
df.shape
# Out:
# (493764, 22)

# %%
len(Delito_unicos)
# Out:
# 298

# %%
filtro = 'HOMICIDIO CULPOSO POR TRÁNSITO VEHICULAR (COLISION)'
HOMICIDIO =df[df["Delito"].isin([filtro])]

# %%
HOMICIDIO
# Out:
#         idCarpeta  Año_inicio Mes_inicio FechaInicio  \
# 45      8828723.0        2021      Enero  2021-01-01
# 169     8828847.0        2021      Enero  2021-01-01
# 2841    8831659.0        2021      Enero  2021-01-07
# 3170    8831997.0        2021      Enero  2021-01-07
# 3208    8832039.0        2021      Enero  2021-01-07
# ...           ...         ...        ...         ...
# 493464  9361602.0        2022  Diciembre  2022-12-31
# 493465  9361602.0        2022  Diciembre  2022-12-31
# 493466  9361602.0        2022  Diciembre  2022-12-31
# 493467  9361602.0        2022  Diciembre  2022-12-31
# 493468  9361602.0        2022  Diciembre  2022-12-31
#
#                                                    Delito  \
# 45      HOMICIDIO CULPOSO POR TRÁNSITO VEHICULAR (COLI...
# 169     HOMICIDIO CULPOSO POR TRÁNSITO VEHICULAR (COLI...
# 2841    HOMICIDIO CULPOSO POR TRÁNSITO VEHICULAR (COLI...
# 3170    HOMICIDIO CULPOSO POR TRÁNSITO VEHICULAR (COLI...
# ...

# %%
dir(pandas)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__deprecated_num_index_names',
#  '__dir__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__getattr__',
#  '__git_version__',
#  '__loader__',
# ...
